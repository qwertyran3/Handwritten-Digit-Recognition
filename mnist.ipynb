# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
# loading dataset and normalizing it
mnist = keras.datasets.mnist
(x_train,y_train),(x_test,y_test) = mnist.load_data()
x = x_test
x_train = keras.utils.normalize(x_train,axis=1)
x_test = keras.utils.normalize(x_test,axis=1)

# %%
import keras.layers as ly
# building the architecture of network
model = keras.models.Sequential();

model.add(ly.Flatten(input_shape=(28,28)))
model.add(ly.Dense(64,activation='relu'))
model.add(ly.Dense(128,activation='relu'))
model.add(ly.Dense(64,activation='relu'))
model.add(ly.Dense(10,activation='softmax'))

# %%
# setting optimizers, lossses , etc...
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
# training the model
model.fit(x_train, y_train, epochs=4)
# Out:
# Epoch 1/4
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.2954 - acc: 0.9102
# Epoch 2/4
# 60000/60000 [==============================] - 5s 79us/step - loss: 0.1261 - acc: 0.9607
# Epoch 3/4
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.0921 - acc: 0.9708
# Epoch 4/4
# 60000/60000 [==============================] - 5s 85us/step - loss: 0.0713 - acc: 0.9774

# %%
# evaluating ...
loss, acc = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', loss)
print('Test accuracy:', acc)
# Out:
# Test loss: 0.1096906685553491
# Test accuracy: 0.9661

# %%
# predicting ...
import numpy as np
import matplotlib.pyplot as plt

predictions = model.predict(x_test)

# %%
idx = 50
plt.imshow(x[idx])
plt.show()
print(np.argmax(predictions[idx]))
# Out:
# 6

# %%
model.save('mnist_model')
